# %% [markdown]
# # Assignment 3

# %%
from numpy import *
#from scipy import *
from numpy import linalg
from scipy import linalg
from scipy import optimize
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MultipleLocator
import math
import sys, getopt, os, string

# %%
# Open file and create vectors x and y
file = open('/home/filip/Documents/NumLinAlg/Assignment 3/signal.dat','r')
x0 = []
y = []
for row, line in enumerate(file, 1):
    fname = line.rstrip().split(',') #using rstrip to remove the \n
    x0.append(float64(fname[0]))
    y.append(float64(fname[1]))

# %% [markdown]
# The signal model is given by
# \begin{equation}
# y(x) = a sin(x) + b cos(x) + c sin(2x) + dcos(2x)
# \end{equation}
# where $a,b,c,d$ are the unknowns. Given the sample data $(x_i,y_i)$ we get from the model the following system of equations
# \begin{equation}
# Ax = y,
# \end{equation}
# where $ x = (a,b,c,d)^T $, y the sampled data $y_i$ and
#
# FEL
# \begin{equation}
# A =
# \begin{bmatrix}
# sin(x_1) & cos(x_1) & sin(2x_1) & cos(2x_1) \\
# sin(x_2) & cos(x_2) & sin(2x_2) & cos(2x_2) \\
# . & . & . & . \\
# . & . & . & . \\
# . & . & . & . \\
# sin(x_n) & cos(x_n) & sin(2x_n) & cos(2x_n) \\
# \end{bmatrix}.
# \end{equation}
#
# Något om hur r vinkelrät mot range(A)  och A^Tr=0

# %%
# Create A for the linear system
A0 = zeros([len(x),4])
for i, xi in enumerate(x0, 1 ):
    A0[int(i)-1,:] = [sin(xi),cos(xi),sin(2*xi),cos(2*xi)]
#A0 = A0.T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [168], in <cell line: 3>()
#       2 A0 = zeros([len(x),3])
#       3 for i, xi in enumerate(x0, 1 ):
# ----> 4     A0[int(i)-1,:] = [sin(xi),cos(xi),sin(2*xi),cos(2*xi)]
#
# ValueError: could not broadcast input array from shape (4,) into shape (3,)

# %% [markdown]
# The system is solved both with QR factorization and with Singular value decomposition

# %%
print(shape(A0))
A = A0.T@A0
b0 = A0.T@y
Q,R = linalg.qr(A)

b = Q@b0

#System solution, could probably find a closed form solution to loop over for models with more parameters in x
x     = zeros([4,1])
x[-1] = b[-1]/R[-1,-1]
x[2]  = (b[2]-R[2,-1]*x[-1] )/R[2,2]
x[1]  = (b[1] - R[1,2]*x[2] - R[1,-1]*x[-1] )/R[1,1]
x[0]  = (b[1] - R[1,2]*x[1] - R[0,-1]*x[2] - R[0,-1]*x[-1] )/R[0,0]

# Visualize result
f,ax=plt.subplots(1)
ax.plot(array(x0),y,'x')
ax.plot(x0,A0@x)
ax.xaxis.set_major_formatter(FuncFormatter(
   lambda val,pos: '{:.0g}$\pi$'.format(val/np.pi) if val !=0 else '0'
))
ax.xaxis.set_major_locator(MultipleLocator(base=np.pi))

plt.show()

linalg.norm(A0@x-y,2)
# Out:
# (200, 4)
# 1863.4664130003166

# %%
U,S,V = linalg.svd(A0.T@A0)


# Solve: S w = U b
b2 = U@b
w  = zeros([4,1])
for i in range(0,4):
    w[i] = b2[i]/S[i]
x = V.T@w


# Visualize result
f,ax=plt.subplots(1)
ax.plot(array(x0),y,'x')
ax.plot(x0,A0@x)
ax.xaxis.set_major_formatter(FuncFormatter(
   lambda val,pos: '{:.0g}$\pi$'.format(val/np.pi) if val !=0 else '0'
))
ax.xaxis.set_major_locator(MultipleLocator(base=np.pi))

plt.show()

linalg.norm(A0@x-y,2)
# Out:
# 1781.1429927167073

# %% [markdown]
# # Task 2

# %% [markdown]
# # Task 4
# Sylvesters criterion.
